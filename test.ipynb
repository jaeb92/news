# %%
import pandas as pd
from db.dbconn import Database

# %%
db = Database()

# %%
conn = db.get_conn()

# %%
df = pd.read_sql("select * from news", con=conn)
# Out:
# /tmp/ipykernel_42407/3747694218.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("select * from news", con=conn)

# %%
df[df['source'] == 'hankook']
# Out:
#                  news_id                                          title  \
# 55  A2023081812460001253       윤 대통령 "하와이 산불 많이 걱정", 바이든 "윤 대통령은 좋은 친구"
# 73  A2023081811210005895               이동관, '아들 학폭 인정하느냐' 묻자 "일부 있었을 것"
# 74  A2023081809210002166       바이든 "평안한 안식 빕니다"... 부친상 치른 윤 대통령에 위로 메시지
# 75  A2023081716000003762  국정원 "김정은, 러시아와 '큰 틀' 군사협력 합의... 北에 기술 이전 가능성"
# 76  A2023081716440001603            국민의힘, 이재명에 "영웅이 개선하는 줄... 피해자 코스프레"
# 77  A2023081716510003661            이재명 소환에 동시다발 압수수색… 민주 "국면 전환용 정치수사"
# 78  A2023081715570005871         야4당, 한미일 정상회의 앞 유엔에 '오염수 방류 저지' 진정서 제출
# 79  A2023081715010005074     한미일 정상, 캠프 데이비드 '원칙'과 '정신' 채택… 오염수 논의 안 한다
# 80  A2023081715290002414           눈물로 소명한 김남국... 국회 윤리특위 이르면 내주 회의서 결론
# 81  A2023081711170004751          이철규 "배 침몰케 하면 승선 못해"...윤상현 "본인이 설명해야"
#
#                                               content author  \
# 55  한미일 정상회의 참석차 미국 워싱턴을 방문한 윤석열 대통령이 17일(현지시간) 조 ...    김현빈
# ...
